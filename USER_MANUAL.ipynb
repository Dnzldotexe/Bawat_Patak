# %% [markdown]
# <a href="https://www.kaggle.com/code/cemprondanziel/user-manual?scriptVersionId=135017914" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Poppins&display=swap"/>
#
#
# <h1 id="bawatpatak" style="font-family: Verdana;">
#     <center>
#         Bawat Patak 💧
#         <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#bawatpatak">¶</a>
#     </center>
# </h1>
# <p>
#     <center style="color: #159364; font-family: Helvetica; font-size: 20px;">
#         A Web App made to Raise Awareness about Water Conservation
#     </center>
#     <center style="color: #000000; font-family: Helvetica; font-size: 17px;">
#         Made by: <b>Danziel Cempron</b> and <b>Ashly Jude Degala</b>
#     </center>
#     <center style="color: #000000; font-family: Helvetica; font-size: 17px;">
#         From Section: <b>SS221</b>
#     </center>
# </p>
#
# ***
#
#
# <center>
#     <img src='https://media3.giphy.com/media/2cDWhvYHsO6y74PFwH/giphy.gif?cid=ecf05e470pftyv8wwzocrfesbkmc5u1d8o92w5ka9y46wa55&ep=v1_stickers_search&rid=giphy.gif&ct=s' height=200px width=300px></center>
#
# ***

# %% [markdown]
# <h1 id="aboutapp" style="font-family:verdana;">
#     <center>
#         1. All about the Application 🧠
#         <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#aboutapp">¶</a>
#     </center>
# </h1>

# %% [markdown]
# <h1 id="problem" style="font-family: Verdana; background-color:#C0AFE2; padding: 20px; display: inline-block;">
#     1.1 Problem to Solve ❓
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#problem">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#DDD5F3; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Throughout the summer, we kept hearing news about water shortages everywhere around Metro Manila. The intense summer heat paired with depleting Dams causes these shortages.
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 id="do" style="font-family: Verdana; background-color:#C0AFE2; padding: 20px; display: inline-block;">
#     1.2 What can you do? 🤔
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#do">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#DDD5F3; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             What can an individual do to help mitigate these kinds of situations?
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 id="solution" style="font-family: Verdana; background-color:#C0AFE2; padding: 20px; display: inline-block;">
#     1.3 Solution 💡
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#solution">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#DDD5F3; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             By simply logging your everyday water consumption, you can monitor how much water you consume. You would be aware of how much water is or was wasted on things that you wouldn't know that is contributing to your water consumption.
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 id="description" style="font-family: Verdana; background-color:#C0AFE2; padding: 20px; display: inline-block;">
#     1.4 Project Description 📜
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#description">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#DDD5F3; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Bawat Patak, a user-friendly web app designed to raise awareness about water conservation. It allows individuals to effortlessly track and monitor their water consumption, empowering them to make informed decisions and contribute to the collective effort of preserving this precious resource. Every user becomes an advocate for sustainable water practices, ensuring that "bawat patak" counts towards a more water-conscious future.
#         </p>
#     </div>
# </div>
#
# ***

# %% [markdown]
# <h1 id="navi" style="font-family:verdana;">
#     <center>
#         2. Navigating the Application 🐱‍👤
#         <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#navi">¶</a>
#     </center>
# </h1>

# %% [markdown]
# <h1 id="signup" style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     2.1 Signing Up 📝
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#signup">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Paste this link (https://bawat-patak.streamlit.app/) in your browser.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             After pasting the link, you should see the Log In page. Scroll down to see the Sign Up page below.
#         </p>
#     </div>
# </div>
#
# ![Sign Up Blank](https://drive.google.com/uc?export=view&id=184LMv4pW-2H8qyxYUxcl1IiXJ_KU4aig)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Fill in your appropriate credentials.
#         </p>
#     </div>
# </div>
#
# ![Sign Up Filled](https://drive.google.com/uc?export=view&id=1P53kAxlbCjj08B4detqw5x0Gqi6CStzS)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Press the Register button.
#         </p>
#     </div>
# </div>
#
# ![Sign Up Success](https://drive.google.com/uc?export=view&id=1OOCnsSCWdzG6jchowaayKsfuwvPAFiQU)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             After pressing Register, you should see a green confirmation below. If it results to an error, please refresh the website then try again.
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 id="login" style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     2.2 Logging In 🔑
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#login">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Paste this link (https://bawat-patak.streamlit.app/) in your browser.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             After pasting the link, you should see the Log In page.
#         </p>
#     </div>
# </div>
#
# ![Log In Blank](https://drive.google.com/uc?export=view&id=1JflHLP71wtroYZmoU_dNcb1osPhW_TWD)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Input your appropriate Username and Password.
#         </p>
#     </div>
# </div>
#
# ![Log In Filled](https://drive.google.com/uc?export=view&id=1o4DAAg7rN2oeNIOrwZhpqolyi-QlfZmy)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Press Login.
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 id="dashboard" style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     2.3 Dashboard and Logs 📊📄
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#dashboard">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Paste this link (https://bawat-patak.streamlit.app/) in your browser.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             After logging in successfully, you should see an empty Dashboard and Logs page that should look like this:
#         </p>
#     </div>
# </div>
#
# ![Landing Page](https://drive.google.com/uc?export=view&id=1xSZpkrNyf88VTu6TP98N8S3LFbEYIrLM)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             When you have added your data. You should see a Line Chart on your Dashboard and a Logs Table below, it should look like this:
#         </p>
#     </div>
# </div>
#
# ![Landing Page Chart](https://drive.google.com/uc?export=view&id=1ADNHBqEB0BhfXjexKfH5rtIpC-TGtg_a)
#
# ![Landing Page Table](https://drive.google.com/uc?export=view&id=1D_S2a5HJLPxmG8LLR8eOqWfCnjoCl5Xz)

# %% [markdown]
# <h1 id="addlogs" style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     2.3.1 Adding Logs ✍
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#addlogs">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Paste this link (https://bawat-patak.streamlit.app/) in your browser.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             After pasting the link and successfully logging in. You should be able to add data to your logs.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             You can choose the date for the consumption data you have collected.
#         </p>
#     </div>
# </div>
#
# ![Choosing Date](https://drive.google.com/uc?export=view&id=1StRECx1Tt2QF8nkqkRBFSUl6Sh1ZfEi8)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             You can input how much per cubic meters was consumed that day. Consumption must be greater than zero to proceed.
#         </p>
#     </div>
# </div>
#
# ![Adding Consumption](https://drive.google.com/uc?export=view&id=14WK8Qq3dP9MdmZ_our-eFhYlvCJHL2s9)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Press Submit.
#         </p>
#     </div>
# </div>
#
# ![Add Success](https://drive.google.com/uc?export=view&id=1J6nFfoLY81YZPuVnPsa69R0uGFE5jmi_)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             A green confirmation should appear after pressing the submit button. If your data does not appear, simply refresh the website then check again.
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 id="download" style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     2.3.2 Downloading your Data 📩
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#download">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Paste this link (https://bawat-patak.streamlit.app/) in your browser.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             After pasting the link and successfully logging in. You should be able to view your Dashboard and Logs.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             To download your data, you need to have at least one consumption log in your table. Otherwise, the download button wouldn't appear.
#         </p>
#     </div>
# </div>
#
# ![Landing Page](https://drive.google.com/uc?export=view&id=1xSZpkrNyf88VTu6TP98N8S3LFbEYIrLM)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             When you have data in your table, the Download CSV button would automatically appear.
#         </p>
#     </div>
# </div>
#
# ![Add Success](https://drive.google.com/uc?export=view&id=1D_S2a5HJLPxmG8LLR8eOqWfCnjoCl5Xz)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             The downloaded file would be in a Comma Separated Values (CSV) format.
#         </p>
#     </div>
# </div>
#
# ![Downloaded Data](https://drive.google.com/uc?export=view&id=1V3H78z_AuFcq_ov3WTIkHnC2g1QaO0wL)

# %% [markdown]
# <h1 id="aboutpage" style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     2.4 About Page 🤓
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#aboutpage">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Paste this link (https://bawat-patak.streamlit.app/) in your browser.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             After pasting the link and successfully logging in. You should see an arrow pointing to the center on your screen.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             To navigate to the About page, simply click the arrow pointing to the center to reveal the menu options and click the About option.
#         </p>
#     </div>
# </div>
#
# ![Log Out](https://drive.google.com/uc?export=view&id=1Yaza79k8Sq3hH5UQzkxQMhLjAX4Azba1)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             After clicking the About option, you should see the about page.
#         </p>
#     </div>
# </div>
#
# ![About the App](https://drive.google.com/uc?export=view&id=1LigRUlyA4TYBTl09BFmKTBImPwI_qLpW)
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Press the linked below the Project Description to learn more about Water Conservation.
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 id="logout" style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     2.5 Logging Out 😭
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#logout">¶</a>
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Paste this link (https://bawat-patak.streamlit.app/) in your browser.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             After pasting the link and successfully logging in. You should see an arrow pointing to the center on your screen.
#         </p>
#     </div>
# </div>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             To Log Out, simply click the arrow pointing to the center to reveal the menu options and click the Logout button located at the top leftmost side of the screen.
#         </p>
#     </div>
# </div>
#
# ![Log Out](https://drive.google.com/uc?export=view&id=1Yaza79k8Sq3hH5UQzkxQMhLjAX4Azba1)
#
# ***

# %% [markdown]
# <h1 id="credits" style="font-family:verdana;">
#     <center>
#         3. Where Credit is Due 🙌
#         <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#credits">¶</a>
#     </center>
# </h1>

# %% [markdown]
# <h1 id="references" style="font-family: Verdana; background-color:#bbbbbb; padding: 20px; display: inline-block;">
#     3.1 References 🔗
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#references">¶</a>
# </h1>
#
# ## [Streamlit Documentation](https://docs.streamlit.io/)
#
# ## [Coding is Fun](https://www.youtube.com/@CodingIsFun)
#
# ## [Creating Beautiful Notebooks](https://www.kaggle.com/code/shubhamksingh/create-beautiful-notebooks-formatting-tutorial#basics)
#
# ## [Supabase Documentation](https://supabase.com/docs)
#
# ## [Pandas Documentation](https://pandas.pydata.org/docs/)
#
# ## [Streamlit Forum](https://discuss.streamlit.io/)

# %% [markdown]
# <h1 id="inspirations" style="font-family: Verdana; background-color:#bbbbbb; padding: 20px; display: inline-block;">
#     3.2 Inspirations 💪
#     <a class="anchor-link" href="https://www.kaggle.com/code/cemprondanziel/user-manual#inspirations">¶</a>
# </h1>
#
# ## [Nicholas Renotte](https://www.youtube.com/@NicholasRenotte)
#
# ## [Luke Barousse](https://www.youtube.com/@LukeBarousse)
#
# ## [Marionette 👺](https://www.kaggle.com/vencerlanz09)
