# %% [markdown]
# <a href="https://www.kaggle.com/code/cemprondanziel/bawat-patak-user-manual?scriptVersionId=134989514" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Poppins&display=swap"/>
#
#
# <h1 style="font-family: Verdana;">
#     <center>
#         Bawat Patak 💧
#     </center>
# </h1>
# <p>
#     <center style="color: #159364; font-family: Helvetica; font-size: 20px;">
#         A Web App made to Raise Awareness about Water Conservation
#     </center>
# </p>
#
# ***
#
#
# <center>
#     <img src='https://media3.giphy.com/media/2cDWhvYHsO6y74PFwH/giphy.gif?cid=ecf05e470pftyv8wwzocrfesbkmc5u1d8o92w5ka9y46wa55&ep=v1_stickers_search&rid=giphy.gif&ct=s' height=200px width=300px></center>
#
#
# <h1 style="font-family: Verdana; background-color:#FFD700; padding: 20px; display: inline-block;">
#     📚Table of Contents📚
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#fcffc2; padding: 20px;">
#         <ol style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             <li>About the App</li>
#             <li>How to Use the App</li>
#             <li>References</li>
#         </ol>
#     </div>
# </div>
#
# ***

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     1.1 Problem to Solve ❓
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Throughout the summer, we kept hearing news about water shortages everywhere around Metro Manila. The intense summer heat paired with depleting Dams causes these shortages.
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     1.2 What can you do? 🤔
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             What can an individual do to help mitigate these kinds of situations?
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     1.3 Solution 💡
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             By simply logging your everyday water consumption, you can monitor how much water you consume. You would be aware of how much water is or was wasted on things that you wouldn't know that is contributing to your water consumption.
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#7CBDE2; padding: 20px; display: inline-block;">
#     1.4 Project Description 📜
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#ACE7EF; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             Bawat Patak, a user-friendly web app designed to raise awareness about water conservation. It allows individuals to effortlessly track and monitor their water consumption, empowering them to make informed decisions and contribute to the collective effort of preserving this precious resource. Every user becomes an advocate for sustainable water practices, ensuring that "bawat patak" counts towards a more water-conscious future.
#         </p>
#     </div>
# </div>
#
# ***

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#13bd38; padding: 20px; display: inline-block;">
#     2.1 Sign Up 📝
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#b6fcbd; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             image
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#13bd38; padding: 20px; display: inline-block;">
#     2.2 Log In 🔑
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#b6fcbd; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             image
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#13bd38; padding: 20px; display: inline-block;">
#     2.3 Dashboard and Logs 📊📄
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#b6fcbd; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             image
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#13bd38; padding: 20px; display: inline-block;">
#     2.3.1 Adding Logs ✍
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#b6fcbd; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             image
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#13bd38; padding: 20px; display: inline-block;">
#     2.3.2 Downloading your Data
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#b6fcbd; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             image
#         </p>
#     </div>
# </div>

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#13bd38; padding: 20px; display: inline-block;">
#     2.4 About Page
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#b6fcbd; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             image
#         </p>
#     </div>
# </div>
#
# ***

# %% [markdown]
# <h1 style="font-family: Verdana; background-color:#bbbbbb; padding: 20px; display: inline-block;">
#     3.1 References
# </h1>
#
# <div style="display: flex; text-align: left;">
#     <div style="background-color:#dddddd; padding: 20px;">
#         <p style="font-size:20px; font-family:verdana; line-height: 1.7em; margin: 0; padding-left: 20px;">
#             image
#         </p>
#     </div>
# </div>
